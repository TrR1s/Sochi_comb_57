# %%
from itertools import combinations
from subjects import CombType,Deck,DeckTools,Comb5,FixCards
import pandas as pd
from core.config import CSV_FILES_PATH

# %% [markdown]
# ### Fix Cards

# %%
# deck = DeckTools.do_full_deck()

# %%
# set_3 = deck.deal_rnd_cards(2)
# set_3

# %%
# fix_card = FixCards(cards_set = set(set_3))

# %%
# fix_card.suit

# %%
# fix_card.str_key

# %%
# file_name='comb5.csv'
# comb5_df  = pd.read_csv(f'{CSV_FILES_PATH}/{file_name}')

# %%
# comb5_df

# %%
# res= []
# for str_key in comb5_df['str_key']:
#     res.append(fix_card.count_amount_in_deck(str_key,deck))

# %%
# comb5_df['amount'] = res

# %%
# comb5_df
